# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate 5 random blue points
blue_points = np.random.rand(5, 2)

# Generate 4 random green points
green_points = np.random.rand(4, 2)

# Plot blue points
plt.scatter(blue_points[:, 0], blue_points[:, 1], color='blue')

# Plot green points
plt.scatter(green_points[:, 0], green_points[:, 1], color='green')

# Plot translucent blue disks around blue points
max_radius = 0
for blue_point in blue_points:
    max_dist = 0
    for green_point in green_points:
        distance = np.linalg.norm(blue_point - green_point)
        if distance > max_dist:
            max_dist = distance
    if max_dist > max_radius:
        max_radius = max_dist
    
for blue_point in blue_points:
    circle = plt.Circle((blue_point[0], blue_point[1]), max_dist, color='blue', alpha=0.1)
    plt.gca().add_patch(circle)

plt.axis('off')
plt.xlim(-1, 2)
plt.ylim(-1, 2)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
# Plot blue points
plt.scatter(blue_points[:, 0], blue_points[:, 1], color='blue')

# Plot green points
plt.scatter(green_points[:, 0], green_points[:, 1], color='green')

# Plot translucent green disks around green points
max_radius = 0
for green_point in green_points:
    max_dist = 0
    for blue_point in blue_points:
        distance = np.linalg.norm(green_point - blue_point)
        if distance > max_dist:
            max_dist = distance

for green_point in green_points:
    circle = plt.Circle((green_point[0], green_point[1]), max_dist, color='green', alpha=0.1)
    plt.gca().add_patch(circle)

plt.axis('off')
plt.xlim(-1, 2)
plt.ylim(-1, 2)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
# Plot blue points
plt.scatter(blue_points[:, 0], blue_points[:, 1], color='blue')

# Plot green points
plt.scatter(green_points[:, 0], green_points[:, 1], color='green')

plt.axis('off')
plt.xlim(-1,2)
plt.ylim(-1,2)
plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
# Define points
red_points = [(1, 2), (2, 4), (4, 5)]
blue_points = [(1.5, 1.8), (1.9, 3), (4, 6), (5, 6)]

# Plot red points
for point in red_points:
    plt.scatter(point[0], point[1], color='red')

# Plot blue points
for point in blue_points:
    plt.scatter(point[0], point[1], color='blue')

# Draw line segments
segments = [((1, 2), (1.5, 1.8)),
            ((2, 4), (1.9, 3)),
            ((4, 5), (4, 6)),
            ((5,6), (11/2, 11/2))]

for segment in segments:
    plt.plot([segment[0][0], segment[1][0]], [segment[0][1], segment[1][1]], color='black')

# Draw some lines
plt.plot([0, 7], [0, 7], color='black', linestyle='--')
plt.plot([0, 7], [0, 0], color='black')
plt.plot([0, 0], [0, 7], color='black')


# Draw translucent gray box
from matplotlib.patches import Rectangle

box1 = Rectangle((0.5, 1.5), 1, 1, color='gray', alpha=0.2)
plt.gca().add_patch(box1)
box2 = Rectangle((1,3), 2, 2, color='gray', alpha=0.2)
plt.gca().add_patch(box2)
box3 = Rectangle((3,4),2,2,color='gray',alpha=0.2)
plt.gca().add_patch(box3)
box4 = Rectangle((4.5,5.5),1,1,color='gray',alpha=0.2)
plt.gca().add_patch(box4)


plt.axis('off')
plt.axis('equal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from ripser import ripser
from ripser import Rips

# Function to generate noisy points on a unit circle
def generate_points(num_points, noise=0.1):
    angles = np.linspace(0, 2*np.pi, num_points)
    points = np.array([np.cos(angles), np.sin(angles)]).T
    noise_points = noise * np.random.randn(num_points, 2)
    return points + noise_points

# Generate noisy points on a unit circle
points = generate_points(100)

# Compute persistence homology using Ripser
rips = Rips()
diagrams = rips.fit_transform(points)

# Plot point cloud and persistence diagram side by side
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot point cloud
axs[0].scatter(points[:, 0], points[:, 1], color='blue', alpha=0.5)
axs[0].set_aspect('equal', adjustable='box')

# Plot persistence diagram
rips.plot(diagrams, ax=axs[1])

plt.tight_layout()
plt.show()
# Out:
# Rips(maxdim=1, thresh=inf, coeff=2, do_cocycles=False, n_perm = None, verbose=True)
